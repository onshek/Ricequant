# %%
# %%rqalpha_plus -s 20160101 -e 20170731 --account future 100000 -fq 1d -p
# # 上述命令参数可以通过运行 %%rqalpha_plus -h 查看到
#
# def init(context):
#     # 策略初始化运行
#     context.s1 = 'J88'    # 标的为 J88
#     context.FastLen = 9    # 快速均线周期数
#     context.SlowLen = 18    # 慢速均线周期数
#     context.ChLen = 12    # 通道突破的周期数
#     context.ExtraPercentage = 0.003    # 通道突破的幅度（百分比）
#     context.TrailBar = 8    # 多少根 Bar 的最低价作为跟踪止损价
#     context.InitalLots = 0    # 初始进场头寸
#     context.ReBars = 15    # 再进场必须在出厂后多少根 Bar内
#     context.ReEntryChLen = 10    # 再进场通道突破的周期数
#     context.ReEntryLots = 0    # 再进场头寸
#     context.Counter_HH = 0    # 高点计数器
#     context.Counter_LL = 0    # 低点计数器
#     context.Counter_ReBuy = 0
#     context.Counter_ReSell = 0
#     context.HH = 0.0    # 出场时的高点
#     context.HH_15 = 0.0
#     context.LL = 0.0    # 出场时的低点
#     context.LL_15 = 0.0
#     subscribe(context.s1)
#
# def before_trading(context):
#     # 每日开盘前运行
#     pass
#
# def get_close(context, bar_dict):
#     # 每个 bar 数据运行
#     Data = history_bars(context.s1, context.SlowLen + 1, '1d', ['close', 'high', 'low'], skip_suspended=True, include_now=False)    # 取值
#     Close = Data['close'][:-1]
#     High = Data['high'][-(context.ChLen + 1): -1]
#     Low = Data['low'][-(context.ChLen + 1): -1]
#
#     FastMA = Close[-context.FastLen:].mean()
#     #print('FastMA', FastMA)
#     SlowMA = Close.mean()
#     #print('SlowMA', SlowMA)
#     HH_12 = High.max()
#     HH_10 = High[-context.ReEntryChLen:].max()
#     HH_8 = High[-context.TrailBar:].max()
#     LL_12 = Low.min()
#     LL_10 = Low[-context.ReEntryChLen:].min()
#     LL_8 = Low[-context.TrailBar:].min()
#
#     return FastMA, SlowMA, HH_12, HH_10, HH_8, LL_12, LL_10, LL_8
#
# def handle_bar(context, bar_dict):
#
#     BuyQty=context.portfolio.positions[context.s1].buy_quantity
#     SellQty=context.portfolio.positions[context.s1].sell_quantity
#
#     FastMA, SlowMA, HH_12, HH_10, HH_8, LL_12, LL_10, LL_8 = get_close(context, bar_dict)
#     #plot('FastMA', FastMA)
#     #plot('SlowMA', SlowMA)
#
#     if FastMA > SlowMA:
#         if context.Counter_LL > 0:
#             context.Counter_LL = 0
#         context.Counter_HH += 1
#         #print('context.Counter_HH', context.Counter_HH)
#         if context.Counter_HH <= 12:
#             #print('当前价位：', bar_dict[context.s1].high)
#             #print('上升突破价位：', HH_12 * (1 + context.ExtraPercentage))
#             if bar_dict[context.s1].high > HH_12 * (1 - context.ExtraPercentage):
#                 print('上升突破')
#                 if SellQty > 0:
#                     buy_close(context.s1, 1)
#                     print('进场，空头平仓')
#                 if BuyQty == 0:
#                     buy_open(context.s1, 1)
#                     print('进场，多头开仓')
#                     context.Counter_HH = 0
#                     context.Counter_ReSell = 1
#                     context.LL_10 = LL_10
#                     context.LL_15 = bar_dict[context.s1].low
#         if context.Counter_HH == 12:
#             context.Counter_HH = 0
#
#     if FastMA < SlowMA:
#         if context.Counter_HH > 0:
#             context.Counter_HH = 0
#         context.Counter_LL += 1
#         #print('context.Counter_LL', context.Counter_LL)
#         if context.Counter_LL <= 12:
#             #print('当前价位：', bar_dict[context.s1].low)
#             #print('下跌突破价位：', LL_12 * (1 - context.ExtraPercentage))
#             if bar_dict[context.s1].low < LL_12 * (1 + context.ExtraPercentage):
#                 print('下跌突破')
#                 if BuyQty > 0:
#                     sell_close(context.s1, 1)
#                     print('进场，多头平仓')
#                 if SellQty == 0:
#                     sell_open(context.s1, 1)
#                     print('进场，空头开仓')
#                     context.Counter_LL = 0
#                     context.Counter_ReBuy = 1
#                     context.HH_10 = HH_10
#                     context.HH_15 = bar_dict[context.s1].high
#         if context.Counter_LL == 12:
#             context.Counter_LL = 0
#
#     if BuyQty > 0:
#         if bar_dict[context.s1].low < LL_8:
#             sell_close(context.s1, 1)
#             print('出场，多头平仓')
#             context.Counter_ReBuy = 1
#             context.HH_10 = HH_10
#             context.HH_15 = bar_dict[context.s1].high
#
#     if SellQty > 0:
#         if bar_dict[context.s1].high > HH_8:
#             buy_close(context.s1, 1)
#             print('出场，空头平仓')
#             context.Counter_ReSell = 1
#             context.LL_10 = LL_10
#             context.LL_15 = bar_dict[context.s1].low
#
#     if context.Counter_ReBuy > 0:
#         context.HH_15 = max(context.HH_15, bar_dict[context.s1].high)
#         context.Counter_ReBuy += 1
#         if context.HH_15 > context.HH_10:
#             if SellQty > 0:
#                 buy_close(context.s1, 1)
#                 print('再进场，空头平仓')
#             if BuyQty == 0:
#                 buy_open(context.s1, 1)
#                 print('再进场，多头开仓')
#     if context.Counter_ReBuy == 16:
#         context.Counter_ReBuy = 0
#
#     if context.Counter_ReSell > 0:
#         context.LL_15 = min(context.LL_15, bar_dict[context.s1].low)
#         context.Counter_ReSell += 1
#         if context.LL_15 < context.LL_10:
#             if BuyQty > 0:
#                 sell_close(context.s1, 1)
#                 print('再进场，多头平仓')
#             if SellQty == 0:
#                 sell_open(context.s1, 1)
#                 print('再进场，空头开仓')
#     if context.Counter_ReSell == 16:
#         context.Counter_ReSell = 0
#
# def after_trading(context):
#     # 每日收盘后运行
#     pass
# Out:
# [2017-08-07 22:16:45.657803] INFO: system_log: rqdatac use socket ('q-rqdatad', 16003)
# 2016-01-13 INFO 下跌突破
# 2016-01-13 INFO 进场，空头开仓
# 2016-01-14 INFO 下跌突破
# 2016-01-18 INFO 出场，空头平仓
# 2016-01-27 INFO 上升突破
# 2016-10-10 INFO 上升突破
# 2016-10-11 INFO 上升突破
# 2016-10-12 INFO 上升突破
# 2016-10-13 INFO 上升突破
# 2016-10-14 INFO 上升突破
# 2016-10-17 INFO 上升突破
# 2016-10-18 INFO 上升突破
# 2016-10-19 INFO 上升突破
# 2016-10-24 INFO 上升突破
# 2016-10-25 INFO 上升突破
# 2016-10-26 INFO 上升突破
# 2016-10-31 INFO 上升突破
# 2016-11-02 INFO 上升突破
# 2016-11-04 INFO 上升突破
# 2016-11-07 INFO 上升突破
# 2016-11-08 INFO 上升突破
# 2016-11-09 INFO 上升突破
# 2016-11-10 INFO 上升突破
# 2016-11-14 INFO 上升突破
# 2016-12-05 INFO 出场，多头平仓
# 2016-12-22 INFO 下跌突破
# 2016-12-22 INFO 进场，空头开仓
# 2016-12-23 INFO 下跌突破
# 2016-12-26 INFO 下跌突破
# 2016-12-27 INFO 下跌突破
# 2017-01-03 INFO 下跌突破
# 2017-01-04 INFO 下跌突破
# 2017-01-10 WARN 订单被拒单: [J88] 已涨停。
# 2017-01-10 INFO 出场，空头平仓
# 2017-01-11 INFO 出场，空头平仓
# 2017-02-07 INFO 下跌突破
# 2017-02-07 INFO 进场，空头开仓
# 2017-02-10 INFO 下跌突破
# 2017-02-16 INFO 出场，空头平仓
# 2017-02-21 INFO 上升突破
# 2017-02-21 INFO 进场，多头开仓
# 2017-03-01 INFO 上升突破
# 2017-03-02 INFO 上升突破
# 2017-03-06 INFO 上升突破
# 2017-03-13 INFO 上升突破
# 2017-03-14 INFO 上升突破
# 2017-03-15 INFO 上升突破
# 2017-03-17 INFO 上升突破
# 2017-03-20 INFO 上升突破
# 2017-03-27 INFO 上升突破
# 2017-03-30 INFO 上升突破
# 2017-04-05 INFO 出场，多头平仓
# 2017-04-11 INFO 下跌突破
# 2017-04-11 INFO 进场，空头开仓
# 2017-04-12 INFO 下跌突破
# 2017-04-13 INFO 下跌突破
# 2017-04-14 INFO 下跌突破
# 2017-04-19 INFO 下跌突破
# 2017-04-20 INFO 下跌突破
# 2017-05-04 INFO 下跌突破
# 2017-05-05 INFO 下跌突破
# 2017-05-22 INFO 出场，空头平仓
# 2017-05-31 INFO 再进场，空头开仓
# 2017-06-05 INFO 下跌突破
# 2017-06-06 INFO 下跌突破
# 2017-06-14 INFO 出场，空头平仓
# 2017-06-20 INFO 上升突破
# 2017-06-20 INFO 进场，多头开仓
# 2017-06-22 INFO 上升突破
# 2017-06-27 INFO 上升突破
# 2017-06-28 INFO 上升突破
# 2017-06-29 INFO 上升突破
# 2017-07-03 INFO 上升突破
# 2017-07-04 INFO 上升突破
# 2017-07-07 INFO 上升突破
# 2017-07-10 INFO 上升突破
# 2017-07-11 INFO 上升突破
# 2017-07-12 INFO 上升突破
# 2017-07-13 INFO 上升突破
