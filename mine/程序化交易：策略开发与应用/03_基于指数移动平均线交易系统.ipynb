# %%
# %%rqalpha_plus -s 20160101 -e 20170731 --account future 15000 -fq 1d -p -bm J88
# # 上述命令参数可以通过运行 %%rqalpha_plus -h 查看到
#
# import talib
#
# def init(context):
#     # 策略初始化运行
#     context.s1 = 'J88'    # 标的为 J88
#     context.AvgLen1 = 6    # 均线周期参数
#     context.AvgLen2 = 12    # 长均线周期参数
#     context.AvgLen3 = 28    # 更长均线周期参数
#     context.RLength = 4    # 止损均线周期参数
#     context.High = 0.0
#     context.Low = 0.0
#
# def before_trading(context):
#     # 每日开盘前运行
#     pass
#
# def get_data(context, bar_dict):
#     # 每个 bar 数据运行
#     # 取出数据
#     Data = history_bars(context.s1, context.AvgLen3,
#                         '1d', ['close', 'high', 'low'],
#                         skip_suspended=True, include_now=False)
#     Close = Data['close']
#     Range = Data['high'] - Data['low']   # 计算振幅
#
#     High = Data['high'][-1]
#     Low = Data['low'][-1]
#
#     EMA1 = talib.EMA(Close, context.AvgLen1)[-1]
#     EMA2 = talib.EMA(Close, context.AvgLen2)[-1]
#     EMA3 = talib.EMA(Close, context.AvgLen3)[-1]
#     RangeL = talib.SMA(Range[-context.RLength:], context.RLength)[-1]
#
#     return EMA1, EMA2, EMA3, RangeL, High, Low
#
#
# def handle_bar(context, bar_dict):
#     # 每个 bar 数据运行
#
#     BuyQty=context.portfolio.positions[context.s1].buy_quantity    # 多头持仓
#     SellQty=context.portfolio.positions[context.s1].sell_quantity    # 空头持仓
#
#     EMA1, EMA2, EMA3, RangeL, High, Low = get_data(context, bar_dict)
#
#     if EMA1 > EMA2 > EMA3:
#         if BuyQty == 0:
#             buy_open(context.s1, 1)
#             context.Low = Low
#             print('进场，多头开仓')
#
#     if (EMA1 < EMA2) or (EMA1 < (context.Low + RangeL)):
#         if BuyQty > 0:
#             sell_close(context.s1, 1)
#             print('出场，多头平仓')
#
#     if EMA1 < EMA2 < EMA3:
#         if SellQty == 0:
#             sell_open(context.s1, 1)
#             context.High = High
#             print('进场，空头开仓')
#
#     if (EMA1 > EMA2) or (EMA1 > (context.High - RangeL)):
#         if SellQty > 0:
#             buy_close(context.s1, 1)
#             print('出场，空头平仓')
#
#
# def after_trading(context):
#     # 每日收盘后运行
#     pass
# Out:
# [2017-08-11 14:42:07.662800] INFO: system_log: rqdatac use socket ('q-rqdatad', 16003)
# 2016-01-04 INFO 进场，多头开仓
# 2016-01-05 INFO 出场，多头平仓
# 2016-01-06 INFO 进场，多头开仓
# 2016-01-07 INFO 出场，多头平仓
# 2016-01-14 INFO 进场，空头开仓
# 2016-01-15 INFO 出场，空头平仓
# 2016-01-18 INFO 进场，多头开仓
# 2016-01-19 INFO 出场，多头平仓
# 2016-01-20 INFO 进场，多头开仓
# 2016-01-21 INFO 出场，多头平仓
# 2016-01-22 INFO 进场，多头开仓
# 2016-01-25 INFO 出场，多头平仓
# 2016-01-26 INFO 进场，多头开仓
# 2016-01-27 INFO 出场，多头平仓
# 2016-01-28 INFO 进场，多头开仓
# 2016-01-29 INFO 出场，多头平仓
# 2016-02-01 INFO 进场，多头开仓
# 2016-02-02 INFO 出场，多头平仓
# 2016-02-03 INFO 进场，多头开仓
# 2016-02-04 INFO 出场，多头平仓
# 2016-02-05 INFO 进场，多头开仓
# 2016-02-15 INFO 出场，多头平仓
# 2016-02-16 INFO 进场，多头开仓
# 2016-02-17 INFO 出场，多头平仓
# 2016-02-18 INFO 进场，多头开仓
# 2016-02-19 INFO 出场，多头平仓
# 2016-02-22 WARN 订单被拒单: [J88] 已涨停。
# 2016-02-22 INFO 进场，多头开仓
# 2016-02-23 INFO 进场，多头开仓
# 2016-02-24 INFO 出场，多头平仓
# 2016-02-25 INFO 进场，多头开仓
# 2016-02-26 INFO 出场，多头平仓
# 2016-02-29 INFO 进场，多头开仓
# 2016-03-01 INFO 出场，多头平仓
# 2016-03-02 INFO 进场，多头开仓
# 2016-03-03 INFO 出场，多头平仓
# 2016-03-04 INFO 进场，多头开仓
# 2016-03-10 INFO 出场，多头平仓
# 2016-03-11 INFO 进场，多头开仓
# 2016-03-14 INFO 出场，多头平仓
# 2016-03-15 INFO 进场，多头开仓
# 2016-03-16 INFO 出场，多头平仓
# 2016-03-17 INFO 进场，多头开仓
# 2016-03-18 INFO 出场，多头平仓
# 2016-03-21 INFO 进场，多头开仓
# 2016-03-22 INFO 出场，多头平仓
# 2016-03-23 INFO 进场，多头开仓
# 2016-03-24 INFO 出场，多头平仓
# 2016-03-25 INFO 进场，多头开仓
# 2016-03-28 INFO 出场，多头平仓
# 2016-03-29 INFO 进场，多头开仓
# 2016-03-30 INFO 出场，多头平仓
# 2016-03-31 INFO 进场，多头开仓
# 2016-04-01 INFO 出场，多头平仓
# 2016-04-05 INFO 进场，多头开仓
# 2016-04-06 INFO 出场，多头平仓
# 2016-04-07 INFO 进场，多头开仓
# 2016-04-08 INFO 出场，多头平仓
# 2016-04-11 WARN 订单被拒单: [J88] 已涨停。
# 2016-04-11 INFO 进场，多头开仓
# 2016-04-12 WARN 订单被拒单: [J88] 已涨停。
# 2016-04-12 INFO 进场，多头开仓
# 2016-04-13 INFO 进场，多头开仓
# 2016-04-14 INFO 出场，多头平仓
# 2016-04-15 INFO 进场，多头开仓
# 2016-04-18 INFO 出场，多头平仓
# 2016-04-19 INFO 进场，多头开仓
# 2016-04-20 INFO 出场，多头平仓
# 2016-04-21 INFO 进场，多头开仓
# 2016-04-22 INFO 出场，多头平仓
# 2016-04-25 WARN 订单被拒单: [J88] 已涨停。
# 2016-04-25 INFO 进场，多头开仓
# 2016-04-26 INFO 进场，多头开仓
# 2016-04-27 INFO 出场，多头平仓
# 2016-04-28 INFO 进场，多头开仓
# 2016-04-29 INFO 出场，多头平仓
# 2016-05-03 INFO 进场，多头开仓
# 2016-05-04 INFO 出场，多头平仓
# 2016-05-05 INFO 进场，多头开仓
# 2016-05-06 INFO 出场，多头平仓
# 2016-05-13 INFO 进场，空头开仓
# 2016-05-16 INFO 出场，空头平仓
# 2016-05-17 INFO 进场，空头开仓
# 2016-05-18 INFO 出场，空头平仓
# 2016-05-19 INFO 进场，空头开仓
# 2016-05-20 INFO 出场，空头平仓
# 2016-05-23 INFO 进场，空头开仓
# 2016-06-13 INFO 出场，空头平仓
# 2016-06-14 INFO 进场，空头开仓
# 2016-06-15 INFO 出场，空头平仓
# 2016-06-16 INFO 进场，空头开仓
# 2016-06-17 INFO 出场，空头平仓
# 2016-06-20 INFO 进场，空头开仓
# 2016-06-21 INFO 出场，空头平仓
# 2016-06-22 INFO 进场，空头开仓
# 2016-06-23 INFO 出场，空头平仓
# 2016-06-27 INFO 进场，多头开仓
# 2016-06-28 INFO 出场，多头平仓
# 2016-06-29 INFO 进场，多头开仓
# 2016-06-30 INFO 出场，多头平仓
# 2016-07-01 INFO 进场，多头开仓
# 2016-07-04 INFO 出场，多头平仓
# 2016-07-05 INFO 进场，多头开仓
# 2016-07-06 INFO 出场，多头平仓
# 2016-07-07 INFO 进场，多头开仓
# 2016-07-08 INFO 出场，多头平仓
# 2016-07-11 INFO 进场，多头开仓
# 2016-07-12 INFO 出场，多头平仓
# 2016-07-13 INFO 进场，多头开仓
# 2016-07-14 INFO 出场，多头平仓
# 2016-07-15 INFO 进场，多头开仓
# 2016-07-18 INFO 出场，多头平仓
# 2016-07-19 INFO 进场，多头开仓
# 2016-07-20 INFO 出场，多头平仓
# 2016-07-21 INFO 进场，多头开仓
# 2016-07-22 INFO 出场，多头平仓
# 2016-07-25 INFO 进场，多头开仓
# 2016-07-26 INFO 出场，多头平仓
# 2016-07-27 INFO 进场，多头开仓
# 2016-07-28 INFO 出场，多头平仓
# 2016-07-29 INFO 进场，多头开仓
# 2016-08-01 INFO 出场，多头平仓
# 2016-08-02 INFO 进场，多头开仓
# 2016-08-03 INFO 出场，多头平仓
# 2016-08-04 INFO 进场，多头开仓
# 2016-08-05 INFO 出场，多头平仓
# 2016-08-08 WARN 订单被拒单: [J88] 已涨停。
# 2016-08-08 INFO 进场，多头开仓
# 2016-08-09 INFO 进场，多头开仓
# 2016-08-10 INFO 出场，多头平仓
# 2016-08-11 INFO 进场，多头开仓
# 2016-08-12 INFO 出场，多头平仓
# 2016-08-15 INFO 进场，多头开仓
# 2016-08-16 INFO 出场，多头平仓
# 2016-08-17 INFO 进场，多头开仓
# 2016-08-18 INFO 出场，多头平仓
# 2016-08-19 INFO 进场，多头开仓
# 2016-08-22 INFO 出场，多头平仓
# 2016-08-23 INFO 进场，多头开仓
# 2016-08-24 INFO 出场，多头平仓
# 2016-08-25 INFO 进场，多头开仓
# 2016-08-29 INFO 出场，多头平仓
# 2016-08-30 INFO 进场，多头开仓
# 2016-08-31 INFO 出场，多头平仓
# 2016-09-05 INFO 进场，多头开仓
# 2016-09-06 INFO 出场，多头平仓
# 2016-09-07 INFO 进场，多头开仓
# 2016-09-08 INFO 出场，多头平仓
# 2016-09-09 INFO 进场，空头开仓
# 2016-09-12 INFO 出场，空头平仓
# 2016-09-13 INFO 进场，空头开仓
# 2016-09-14 INFO 出场，空头平仓
# 2016-09-19 INFO 进场，空头开仓
# 2016-09-20 INFO 出场，空头平仓
# 2016-09-21 INFO 进场，空头开仓
# 2016-09-22 INFO 出场，空头平仓
# 2016-09-27 INFO 进场，多头开仓
# 2016-09-28 INFO 出场，多头平仓
# 2016-09-29 INFO 进场，多头开仓
# 2016-09-30 INFO 出场，多头平仓
# 2016-10-10 INFO 进场，多头开仓
# 2016-10-11 INFO 出场，多头平仓
# 2016-10-12 INFO 进场，多头开仓
# 2016-10-13 INFO 出场，多头平仓
# 2016-10-14 INFO 进场，多头开仓
# 2016-10-17 INFO 出场，多头平仓
# 2016-10-18 INFO 进场，多头开仓
# 2016-10-19 INFO 出场，多头平仓
# 2016-10-20 INFO 进场，多头开仓
# 2016-10-21 INFO 出场，多头平仓
# 2016-10-24 INFO 进场，多头开仓
# 2016-10-25 INFO 出场，多头平仓
# 2016-10-26 INFO 进场，多头开仓
# 2016-10-27 INFO 出场，多头平仓
# 2016-10-28 INFO 进场，多头开仓
# 2016-10-31 INFO 出场，多头平仓
# 2016-11-01 INFO 进场，多头开仓
# 2016-11-02 INFO 出场，多头平仓
# 2016-11-03 INFO 进场，多头开仓
# 2016-11-04 INFO 出场，多头平仓
# 2016-11-07 WARN 订单被拒单: [J88] 已涨停。
# 2016-11-07 INFO 进场，多头开仓
# 2016-11-08 INFO 进场，多头开仓
# 2016-11-09 INFO 出场，多头平仓
# 2016-11-10 INFO 进场，多头开仓
# 2016-11-11 INFO 出场，多头平仓
# 2016-11-14 INFO 进场，多头开仓
# 2016-11-15 INFO 出场，多头平仓
# 2016-11-16 INFO 进场，多头开仓
# 2016-11-17 INFO 出场，多头平仓
# 2016-11-18 INFO 进场，多头开仓
# 2016-11-21 INFO 出场，多头平仓
# 2016-11-22 WARN 订单被拒单: [J88] 已涨停。
# 2016-11-22 INFO 进场，多头开仓
# 2016-11-23 INFO 进场，多头开仓
# 2016-11-24 INFO 出场，多头平仓
# 2016-11-25 INFO 进场，多头开仓
# 2016-11-28 INFO 出场，多头平仓
# 2016-11-29 INFO 进场，多头开仓
# 2016-11-30 INFO 出场，多头平仓
# 2016-12-01 INFO 进场，多头开仓
# 2016-12-02 INFO 出场，多头平仓
# 2016-12-06 INFO 进场，空头开仓
# 2016-12-07 INFO 出场，空头平仓
# 2016-12-08 INFO 进场，空头开仓
# 2016-12-09 INFO 出场，空头平仓
# 2016-12-12 INFO 进场，空头开仓
# 2016-12-13 INFO 出场，空头平仓
# 2016-12-14 INFO 进场，空头开仓
# 2016-12-15 INFO 出场，空头平仓
# 2016-12-16 INFO 进场，空头开仓
# 2016-12-19 INFO 出场，空头平仓
# 2016-12-20 INFO 进场，空头开仓
# 2016-12-21 INFO 出场，空头平仓
# 2016-12-22 INFO 进场，空头开仓
# 2016-12-23 INFO 出场，空头平仓
# 2016-12-26 INFO 进场，空头开仓
# 2016-12-27 INFO 出场，空头平仓
# 2016-12-28 INFO 进场，空头开仓
# 2016-12-29 INFO 出场，空头平仓
# 2016-12-30 INFO 进场，空头开仓
# 2017-01-03 INFO 出场，空头平仓
# 2017-01-04 INFO 进场，空头开仓
# 2017-01-05 INFO 出场，空头平仓
# 2017-01-06 INFO 进场，空头开仓
# 2017-01-09 INFO 出场，空头平仓
# 2017-01-10 INFO 进场，空头开仓
# 2017-01-11 INFO 出场，空头平仓
# 2017-01-18 INFO 进场，多头开仓
# 2017-01-19 INFO 出场，多头平仓
# 2017-01-20 INFO 进场，多头开仓
# 2017-01-23 INFO 出场，多头平仓
# 2017-01-26 INFO 进场，多头开仓
# 2017-02-03 INFO 出场，多头平仓
# 2017-02-08 INFO 进场，空头开仓
# 2017-02-09 INFO 出场，空头平仓
# 2017-02-10 INFO 进场，空头开仓
# 2017-02-13 INFO 出场，空头平仓
# 2017-02-14 INFO 进场，多头开仓
# 2017-02-15 INFO 出场，多头平仓
# 2017-02-16 INFO 进场，多头开仓
# 2017-02-17 INFO 出场，多头平仓
# 2017-02-20 INFO 进场，多头开仓
# 2017-02-21 INFO 出场，多头平仓
# 2017-02-22 INFO 进场，多头开仓
# 2017-02-23 INFO 出场，多头平仓
# 2017-02-24 INFO 进场，多头开仓
# 2017-02-27 INFO 出场，多头平仓
# 2017-02-28 INFO 进场，多头开仓
# 2017-03-01 INFO 出场，多头平仓
# 2017-03-02 INFO 进场，多头开仓
# 2017-03-03 INFO 出场，多头平仓
# 2017-03-06 INFO 进场，多头开仓
# 2017-03-07 INFO 出场，多头平仓
# 2017-03-08 INFO 进场，多头开仓
# 2017-03-09 INFO 出场，多头平仓
# 2017-03-10 INFO 进场，多头开仓
# 2017-03-13 INFO 出场，多头平仓
# 2017-03-14 INFO 进场，多头开仓
# 2017-03-15 INFO 出场，多头平仓
# 2017-03-16 INFO 进场，多头开仓
# 2017-03-17 INFO 出场，多头平仓
# 2017-03-20 INFO 进场，多头开仓
# 2017-03-21 INFO 出场，多头平仓
# 2017-03-22 INFO 进场，多头开仓
# 2017-03-23 INFO 出场，多头平仓
# 2017-03-24 INFO 进场，多头开仓
# 2017-03-27 INFO 出场，多头平仓
# 2017-03-28 INFO 进场，多头开仓
# 2017-03-29 INFO 出场，多头平仓
# 2017-03-30 INFO 进场，多头开仓
# 2017-03-31 INFO 出场，多头平仓
# 2017-04-05 INFO 进场，多头开仓
# 2017-04-07 INFO 出场，多头平仓
# 2017-04-11 INFO 进场，空头开仓
# 2017-04-12 INFO 出场，空头平仓
# 2017-04-13 INFO 进场，空头开仓
# 2017-04-14 INFO 出场，空头平仓
# 2017-04-17 INFO 进场，空头开仓
# 2017-04-18 INFO 出场，空头平仓
# 2017-04-19 INFO 进场，空头开仓
# 2017-04-20 INFO 出场，空头平仓
# 2017-04-21 INFO 进场，空头开仓
# 2017-04-24 INFO 出场，空头平仓
# 2017-04-25 INFO 进场，空头开仓
# 2017-04-26 INFO 出场，空头平仓
# 2017-04-27 INFO 进场，空头开仓
# 2017-04-28 INFO 出场，空头平仓
# 2017-05-02 INFO 进场，空头开仓
# 2017-05-22 INFO 出场，空头平仓
# 2017-05-25 INFO 进场，空头开仓
# 2017-05-26 INFO 出场，空头平仓
# 2017-05-31 INFO 进场，空头开仓
# 2017-06-14 INFO 出场，空头平仓
# 2017-06-20 INFO 进场，多头开仓
# 2017-06-21 INFO 出场，多头平仓
# 2017-06-22 INFO 进场，多头开仓
# 2017-06-23 INFO 出场，多头平仓
# 2017-06-26 INFO 进场，多头开仓
# 2017-06-27 INFO 出场，多头平仓
# 2017-06-28 INFO 进场，多头开仓
# 2017-06-29 INFO 出场，多头平仓
# 2017-06-30 INFO 进场，多头开仓
# 2017-07-03 INFO 出场，多头平仓
# 2017-07-04 INFO 进场，多头开仓
# 2017-07-05 INFO 出场，多头平仓
# 2017-07-06 INFO 进场，多头开仓
# 2017-07-07 INFO 出场，多头平仓
# 2017-07-10 INFO 进场，多头开仓
# 2017-07-11 INFO 出场，多头平仓
# 2017-07-12 INFO 进场，多头开仓
# 2017-07-13 INFO 出场，多头平仓
# 2017-07-14 INFO 进场，多头开仓
